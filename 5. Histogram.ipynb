# %% [markdown]
# # Histogram
#
# - is to check the distribution of the data along any particular scale
# - univarient

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.hist(df.CO2EMISSIONS)
plt.show()

# %%
# histogram of engine size

plt.hist(df.CO2EMISSIONS, bins = 8)
plt.show()

#inferance
#in given dataset more than 70% of the cars have less than 4 litre cars having engine size greater than 4 are less than 30%

# %%
# display the bar graph of car ccomanies who emit co2 more than 300 ppm 

df_co2300 = df[df.CO2EMISSIONS > 300]

plt.bar(df_co2300.MAKE, df_co2300.CO2EMISSIONS)
plt.xticks(rotation = 90)
plt.show()

# %%
# display the bar graph of car companies who emit co2 more than 300ppm and engine size more than 4

df_ce = df[(df.CO2EMISSIONS > 300) & (df.ENGINESIZE > 4)]
df_ce.head(2)

plt.figure(figsize = (20,6))
plt.bar(df_ce.MAKE, df_ce.CO2EMISSIONS, width = 0.4)
plt.xticks(rotation = 90)
plt.show()

# %%
# display the bar graph for car company which make the more than two model of cars

a = df.
