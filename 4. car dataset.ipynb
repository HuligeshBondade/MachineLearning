# %%
path = 'C:/Users/Huligesh/Desktop/Internship/Dataset/'

file_name = 'Data.csv'
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
print('libraries imported successfully')
# Out:
# libraries imported successfully

# %%
path = 'C:/Users/Huligesh/Desktop/Abeyaantrix Internship/Dataset/'
file_name = 'Emission.csv'
df = pd.read_csv(path + file_name)
df
# Out:
#       MODELYEAR   MAKE       MODEL    VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 0          2014  ACURA         ILX         COMPACT         2.0          4
# 1          2014  ACURA         ILX         COMPACT         2.4          4
# 2          2014  ACURA  ILX HYBRID         COMPACT         1.5          4
# 3          2014  ACURA     MDX 4WD     SUV - SMALL         3.5          6
# 4          2014  ACURA     RDX AWD     SUV - SMALL         3.5          6
# ...         ...    ...         ...             ...         ...        ...
# 1062       2014  VOLVO    XC60 AWD     SUV - SMALL         3.0          6
# 1063       2014  VOLVO    XC60 AWD     SUV - SMALL         3.2          6
# 1064       2014  VOLVO    XC70 AWD     SUV - SMALL         3.0          6
# 1065       2014  VOLVO    XC70 AWD     SUV - SMALL         3.2          6
# 1066       2014  VOLVO    XC90 AWD  SUV - STANDARD         3.2          6
#
#      TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# ...

# %% [markdown]
# - modelyear : year of MAF
# - MAKE : manufacturing company name
# - MODEL : version of car within a class
# - VEHICLECLASS : type of car small(compact),sedan,suv etc
# - ENGINESIZE : this will decide power output of the car
# - larger the size more powerfull the car
# - CYLINDER : directly proportion to car power and engine size
# - TRANSMISSION TYPE : car transmission decide how the vehicle engine is cotrol
# - manual gear shifts, atomatic etc
# - co2 which is measure in ppl, more the value more is population

# %%
[R,C] = df.shape
print('Dataset has %d rows and %d column'%(R,C))
print('below is the list of column\n',df.columns)
# Out:
# Dataset has 1067 rows and 13 column
# below is the list of column
#  Index(['MODELYEAR', 'MAKE', 'MODEL', 'VEHICLECLASS', 'ENGINESIZE', 'CYLINDERS',
#        'TRANSMISSION', 'FUELTYPE', 'FUELCONSUMPTION_CITY',
#        'FUELCONSUMPTION_HWY', 'FUELCONSUMPTION_COMB',
#        'FUELCONSUMPTION_COMB_MPG', 'CO2EMISSIONS'],
#       dtype='object')

# %%
# what are highest and lowest levels of co2 emission 
co2max = df.CO2EMISSIONS.max()
co2min = df.CO2EMISSIONS.min()

print('''Heighest and lowest of co2 emission in the given dataset are %d and %d'''%(co2max,co2min))
# Out:
# Heighest and lowest of co2 emission in the given dataset are 488 and 108

# %%
# how many car brands are present and what are the names of the same 

print('Car brand names = \n',df.MAKE.unique())
print('there are total %d brands are present' %(len(df.MAKE.unique())))
# Out:
# Car brand names =
#  ['ACURA' 'ASTON MARTIN' 'AUDI' 'BENTLEY' 'BMW' 'BUICK' 'CADILLAC'
#  'CHEVROLET' 'CHRYSLER' 'DODGE' 'FIAT' 'FORD' 'GMC' 'HONDA' 'HYUNDAI'
#  'INFINITI' 'JAGUAR' 'JEEP' 'KIA' 'LAMBORGHINI' 'LAND ROVER' 'LEXUS'
#  'LINCOLN' 'MASERATI' 'MAZDA' 'MERCEDES-BENZ' 'MINI' 'MITSUBISHI' 'NISSAN'
#  'PORSCHE' 'RAM' 'ROLLS-ROYCE' 'SCION' 'SMART' 'SRT' 'SUBARU' 'TOYOTA'
#  'VOLKSWAGEN' 'VOLVO']
# there are total 39 brands are present

# %%
# types of fuel used and which is uesd more
print(df.FUELTYPE.unique())
print(df.FUELTYPE.value_counts())
print(df.FUELTYPE.max())
print('-'*25)

# average of engine size
print(df.ENGINESIZE.mean())
print('-'*25)

# how many car engine size more than 4
es = df.ENGINESIZE > 4
print(df[['ENGINESIZE']][es])
print('car engines are',df.ENGINESIZE[df.ENGINESIZE > 4].count())
print('-'*25)

#how many cars have less than 3 cylinders
print('cylinders have',df.CYLINDERS[df.CYLINDERS < 3].count())
# Out:
# ['Z' 'D' 'X' 'E']
# X    514
# Z    434
# E     92
# D     27
# Name: FUELTYPE, dtype: int64
# Z
# -------------------------
# 3.346298031865042
# -------------------------
#       ENGINESIZE
# 12           5.9
# 13           5.9
# 14           4.7
# 15           4.7
# 16           4.7
# ...          ...
# 993          5.7
# 1004         4.6
# 1005         5.7
# 1006         4.6
# 1007         5.7
#
# [278 rows x 1 columns]
# car engines are 278
# -------------------------
# cylinders have 0

# %% [markdown]
# # Visualization

# %%
df.describe()
# Out:
#        MODELYEAR   ENGINESIZE    CYLINDERS  FUELCONSUMPTION_CITY  \
# count     1067.0  1067.000000  1067.000000           1067.000000
# mean      2014.0     3.346298     5.794752             13.296532
# std          0.0     1.415895     1.797447              4.101253
# min       2014.0     1.000000     3.000000              4.600000
# 25%       2014.0     2.000000     4.000000             10.250000
# 50%       2014.0     3.400000     6.000000             12.600000
# 75%       2014.0     4.300000     8.000000             15.550000
# max       2014.0     8.400000    12.000000             30.200000
#
#        FUELCONSUMPTION_HWY  FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  \
# count          1067.000000           1067.000000               1067.000000
# mean              9.474602             11.580881                 26.441425
# std               2.794510              3.485595                  7.468702
# min               4.900000              4.700000                 11.000000
# ...

# %%
# engine size vs co2 emission

plt.figure(figsize = (4,4))
plt.plot(df.ENGINESIZE, df.CO2EMISSIONS)
plt.show()

# %%
plt.figure(figsize = (4,4))
plt.scatter(df.ENGINESIZE, df.CO2EMISSIONS)
plt.show()
print('As the engine size increases co2 also increases')
# Out:
# As the engine size increases co2 also increases

# %%
# cylinders vs co2 emission scatter plot

plt.figure(figsize = (4,4))
plt.scatter(df.CYLINDERS, df.CO2EMISSIONS)
plt.show()
print('As the cylinders increases co2 also increasing')
# Out:
# As the cylinders increases co2 also increasing

# %%
# fueltype vs co2 emission

plt.figure(figsize = (4,4))
plt.bar(df.FUELTYPE, df.CO2EMISSIONS)
plt.show()

# %%
# make vs co2 emission

plt.figure(figsize = (10,4))
plt.bar(df.MAKE, df.CO2EMISSIONS)
plt.xticks(rotation = 90)
plt.show()
